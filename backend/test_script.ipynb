# %%
import requests
import os
from langchain_openai import ChatOpenAI
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.document_loaders import DirectoryLoader, JSONLoader
from langchain_community.vectorstores import FAISS

# %%
os.environ["OPENROUTER_API_KEY"] = "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"
OPENROUTER_BASE_URL = "https://openrouter.ai/api/v1"

# You need a REAL OpenAI API key for embeddings (not OpenRouter)
# Get it from: https://platform.openai.com/api-keys

# %%
loader = DirectoryLoader(
    "data/",
    glob="**/*.json",
    loader_cls=JSONLoader,
    show_progress=True,
    loader_kwargs={"jq_schema": ".", "text_content": False}
)
docs = loader.load()
print(len(docs), "documents loaded.")
# Out:
# 100%|██████████| 25/25 [00:00<00:00, 30.66it/s]
# 25 documents loaded.

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
splitter = RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=200)
chunks = splitter.split_documents(docs)

embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

vectorstore = FAISS.from_documents(chunks,embeddings)
retriever = vectorstore.as_retriever(search_kwargs={"k":10})

# %%
llm = ChatOpenAI(
    model = "openai/gpt-oss-120b:free",
    temperature = 0.6, 
    openai_api_key=os.environ["OPENROUTER_API_KEY"],
    openai_api_base=OPENROUTER_BASE_URL,
    max_tokens = 10000,
    default_headers={
        "HTTP-Referer": "http://localhost:3000", \
        "X-Title": "My RAG App"
    },
)

# %%
def rag_answer(query: str) -> str:
    relevant_docs = retriever.invoke(query)
    context = "\n".join([doc.page_content for doc in relevant_docs])
    prompt = f"""
    Answer the question based on the context below and give the accurate result from this  and list donw the jobs as bullet points and give a detailed description of about the job :\n\nContext: {context}\n\nQuestion: {query}\n\nAnswer: 
     also if you dont know the answer tell the user that you don't know the answer for the specific question
    """
    response = llm.invoke(prompt)
    clr = response.content.replace("**","")
    return clr

query = "machine learning engineer jobs list them out"
answer = rag_answer(query)
print(answer)
# Out:
# Machine‑Learning‑Engineer positions found in the supplied data
#
# | # | Job title (as listed) | Location / Work‑mode | Employment type | Core responsibilities & highlights |
# |---|-----------------------|----------------------|-----------------|--------------------------------------|
# | 1 | AI/ML Engineer (Remote) – Contractual (3 months) | Remote – India | 3‑month contract | • Build efficient, data‑driven AI systems that power predictive‑automation features.<br>• Apply strong statistics & programming skills to assess, analyse and organise large data sets.<br>• Design, test and optimise machine‑learning models and algorithms. |
# | 2 | Senior Machine Learning Engineer | Chennai, Tamil Nadu, India | Full‑time (permanent) | • Research, design and implement advanced ML algorithms to solve business challenges.<br>• Perform ETL of large data sets into a PostgreSQL data‑warehouse.<br>• Deploy models to production, ensuring performance, scalability and monitoring. |
# | 3 | Machine Learning Engineer (Stier Solutions Inc.) | Hyderabad, Telangana, India | Full‑time – On‑site / Hybrid | • Design, build and deploy scalable ML models that address real‑world problems.<br>• Work closely with data scientists, data engineers and product teams to move models from experimentation to production.<br>• Maintain model‑serving pipelines and monitor model health. |
# | 4 | Senior Machine Learning Engineer (Diligente Technologies) | Bengaluru (Bellandur), Karnataka – Hybrid (2 days on‑site/week) | Full‑time | • Lead R&D of AI models ranging from simple classifiers to fine‑tuned LLMs.<br>• Design, implement and ship AI‑based solutions for product and business use‑cases.<br>• Define best‑practice strategies for model versioning, testing and deployment. |
# | 5 | Principal Machine Learning Engineer | London, United Kingdom (sponsorship provided) | Permanent | • Senior technical leader in a Data‑Science team; design, develop and deploy cutting‑edge ML solutions.<br>• Expertise required in generative AI, computer‑vision, NLP, deep‑learning and cloud platforms.<br>• Mentor junior engineers and drive the overall ML roadmap. |
# | 6 | AI‑ML Engineer (The HIRD) | Chennai, Tamil Nadu, India | Full‑time | • 8‑10 years overall experience; 3‑5 years on AI/ML projects.<br>• Core tools: Python (NumPy, Pandas, Scikit‑learn, Seaborn), SQL.<br>• Specialises in Generative AI & LLMs (OpenAI GPT, Gemini, LLaMA, Claude), prompt engineering, Retrieval‑Augmented Generation (FAISS, ChromaDB, PGVector).<br>• Frameworks: LangChain, Langfuse, LlamaIndex, LangGraph, Autogen, Google ADK. |
# | 7 | Python & Machine Learning Engineer (Taiyō.AI) | Remote – India | Contract‑to‑Hire (3 months) | • 9 years experience building advanced ML, NLP and LLM‑based systems.<br>• Design & implement machine‑learning & deep‑learning solutions; optimise models for production deployment.<br>• Work on Transformers, large‑language‑model pipelines and model‑serving infrastructure. |
# | 8 | AI Engineer – Computer Vision & Geospatial AI | Bangalore, Karnataka, India (On‑site) | Full‑time | • 2 years experience building end‑to‑end AI solutions.<br>• Focus on computer‑vision, LiDAR and sensor data processing.<br>• Tech stack: Python, PyTorch / TensorFlow, image & sensor data pipelines. |
# | 9 | Artificial Intelligence Engineer (TalentBridge) | Bengaluru or Pune, India – Hybrid (3 days on‑site, 2 days remote) | 6‑month contract‑to‑hire | • 5‑10 years experience with Python, PyTorch, TensorFlow, PySpark, Scikit‑learn, SQL.<br>• Deep expertise in LLMs & Generative AI (LangChain, Hugging Face, OpenAI GPT, Gemini).<br>• Build, fine‑tune and deploy AI/ML models; create RAG pipelines (FAISS, ChromaDB, PGVector). |
#
# ### Quick‑look summary (bullet list)
#
# - AI/ML Engineer (Remote) – 3‑month contract – DataOrbit AI; remote work in India; focus on building predictive‑automation AI systems.
# - Senior Machine Learning Engineer – Chennai – Full‑time; model research, ETL to Postgres, production deployment.
# - Machine Learning Engineer – Hyderabad – Stier Solutions; full‑time hybrid; end‑to‑end model development & deployment.
# - Senior Machine Learning Engineer – Bengaluru – Diligente Technologies; hybrid; R&D on classifiers and LLM fine‑tuning.
# - Principal Machine Learning Engineer – London – Permanent; senior leadership on generative AI, CV, NLP, cloud‑based ML.
# - AI‑ML Engineer – Chennai – The HIRD; senior role with strong Python/SQL and Generative‑AI/LLM expertise.
# - Python & Machine Learning Engineer – Remote – Taiyō.AI; contract‑to‑hire; advanced ML/NLP/LLM system design.
# - AI Engineer – Bangalore – Computer‑vision & geospatial AI; full‑time onsite; deep‑learning on image & LiDAR data.
# - Artificial Intelligence Engineer – Bengaluru/Pune – TalentBridge; hybrid; extensive work with LLMs, LangChain, RAG pipelines.
#
# These are all the machine‑learning‑engineer‑type openings that appear in the provided context. If you need more detail on any specific posting (e.g., salary, exact posting date, or application link), let me know!
